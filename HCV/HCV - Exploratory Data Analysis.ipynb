# %% [markdown]
# # HCV Data set

# %%
data2 = pd.read_csv('HCV.csv')

# %%
data2
# Out:
#      Unnamed: 0       Category  Age Sex   ALB    ALP    ALT    AST   BIL  \
# 0             1  0=Blood Donor   32   m  38.5   52.5    7.7   22.1   7.5
# 1             2  0=Blood Donor   32   m  38.5   70.3   18.0   24.7   3.9
# 2             3  0=Blood Donor   32   m  46.9   74.7   36.2   52.6   6.1
# 3             4  0=Blood Donor   32   m  43.2   52.0   30.6   22.6  18.9
# 4             5  0=Blood Donor   32   m  39.2   74.1   32.6   24.8   9.6
# ..          ...            ...  ...  ..   ...    ...    ...    ...   ...
# 610         611    3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0
# 611         612    3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0
# 612         613    3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0
# 613         614    3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0
# 614         615    3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0
#
#        CHE  CHOL   CREA    GGT  PROT
# 0     6.93  3.23  106.0   12.1  69.0
# ...

# %%
data2.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
data2.tail()
# Out:
#      Unnamed: 0     Category  Age Sex   ALB    ALP    ALT    AST   BIL   CHE  \
# 610         611  3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0  5.57
# 611         612  3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0  1.54
# 612         613  3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0  1.66
# 613         614  3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0  3.56
# 614         615  3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0  9.07
#
#      CHOL  CREA    GGT  PROT
# 610  6.30  55.7  650.9  68.5
# 611  3.02  63.0   35.9  71.3
# 612  3.63  66.7   64.2  82.0
# 613  4.20  52.0   50.0  71.0
# 614  5.30  67.0   34.0  68.0

# %%
data2.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST',
#        'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
data2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data2.columns
# Out:
# Index(['Category', 'Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE',
#        'CHOL', 'CREA', 'GGT', 'PROT'],
#       dtype='object')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       614 non-null    float64
#  4   ALP       597 non-null    float64
#  5   ALT       614 non-null    float64
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    float64
#  9   CHOL      605 non-null    float64
#  10  CREA      615 non-null    float64
#  11  GGT       615 non-null    float64
#  12  PROT      614 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 62.6+ KB

# %%
data2.shape
# Out:
# (615, 13)

# %%
data2.isnull().sum()
# Out:
# Category     0
# Age          0
# Sex          0
# ALB          1
# ALP         18
# ALT          1
# AST          0
# BIL          0
# CHE          0
# CHOL        10
# CREA         0
# GGT          0
# PROT         1
# dtype: int64

# %%
data2.describe(include='all')
# Out:
#              Category         Age  Sex         ALB         ALP         ALT  \
# count             615  615.000000  615  614.000000  597.000000  614.000000
# unique              5         NaN    2         NaN         NaN         NaN
# top     0=Blood Donor         NaN    m         NaN         NaN         NaN
# freq              533         NaN  377         NaN         NaN         NaN
# mean              NaN   47.408130  NaN   41.620195   68.283920   28.450814
# std               NaN   10.055105  NaN    5.780629   26.028315   25.469689
# min               NaN   19.000000  NaN   14.900000   11.300000    0.900000
# 25%               NaN   39.000000  NaN   38.800000   52.500000   16.400000
# 50%               NaN   47.000000  NaN   41.950000   66.200000   23.000000
# 75%               NaN   54.000000  NaN   45.200000   80.100000   33.075000
# max               NaN   77.000000  NaN   82.200000  416.600000  325.300000
#
# ...

# %%
data2['Category'].unique()
# Out:
# array(['0=Blood Donor', '0s=suspect Blood Donor', '1=Hepatitis',
#        '2=Fibrosis', '3=Cirrhosis'], dtype=object)

# %%
data2.nunique()
# Out:
# Category      5
# Age          49
# Sex           2
# ALB         189
# ALP         414
# ALT         341
# AST         297
# BIL         188
# CHE         407
# CHOL        313
# CREA        117
# GGT         358
# PROT        198
# dtype: int64

# %%
data2['Sex'].value_counts()
# Out:
# m    377
# f    238
# Name: Sex, dtype: int64

# %%
data2['Category'].value_counts()
# Out:
# 0=Blood Donor             533
# 3=Cirrhosis                30
# 1=Hepatitis                24
# 2=Fibrosis                 21
# 0s=suspect Blood Donor      7
# Name: Category, dtype: int64

# %%
data2['Category'].value_counts()/len(data2['Category'])*100
# Out:
# 0=Blood Donor             86.666667
# 3=Cirrhosis                4.878049
# 1=Hepatitis                3.902439
# 2=Fibrosis                 3.414634
# 0s=suspect Blood Donor     1.138211
# Name: Category, dtype: float64

# %%
data2['ALP'].fillna(data2['ALP'].mean, inplace=True)

# %%
data2['ALB'].fillna(data2['ALT'].mean, inplace=True)

# %%
data2['PROT'].fillna(data2['PROT'].mean, inplace=True)

# %%
data2['ALT'].fillna(data2['ALT'].mean, inplace=True)

# %%
data2['CHOL'].fillna(data2['CHOL'].mean, inplace=True)

# %%
data2.isnull().sum()
# Out:
# Category    0
# Age         0
# Sex         0
# ALB         0
# ALP         0
# ALT         0
# AST         0
# BIL         0
# CHE         0
# CHOL        0
# CREA        0
# GGT         0
# PROT        0
# dtype: int64

# %%
data2.corr()
# Out:
#            Age       AST       BIL       CHE      CREA       GGT
# Age   1.000000  0.088666  0.032492 -0.075093 -0.022296  0.153087
# AST   0.088666  1.000000  0.312231 -0.208536 -0.021387  0.491263
# BIL   0.032492  0.312231  1.000000 -0.333172  0.031224  0.217024
# CHE  -0.075093 -0.208536 -0.333172  1.000000 -0.011157 -0.110345
# CREA -0.022296 -0.021387  0.031224 -0.011157  1.000000  0.121003
# GGT   0.153087  0.491263  0.217024 -0.110345  0.121003  1.000000

# %%
correlation = data2.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns)
# Out:
# <AxesSubplot:>

# %%
data2.ALB.values
# Out:
# array([38.5, 38.5, 46.9, 43.2, 39.2, 41.6, 46.3, 42.2, 50.9, 42.4, 44.3,
#        46.4, 36.3, 39.0, 38.7, 41.8, 40.9, 45.2, 36.6, 42.0, 44.3, 46.7,
#        42.7, 43.4, 40.5, 44.8, 42.6, 29.0, 44.6, 46.8, 41.8, 46.1, 43.6,
#        37.5, 42.1, 44.7, 41.5, 48.7, 47.3, 44.5, 47.4, 51.0, 27.8, 46.1,
#        45.5, 41.7, 45.9, 48.7, 53.0, 47.8, 42.6, 42.4, 48.9, 31.4, 42.9,
#        44.0, 41.5, 47.9, 44.8, 38.6, 51.2, 41.9, 46.1, 50.4, 33.9, 42.9,
#        40.8, 43.6, 46.4, 48.7, 48.1, 39.9, 45.5, 43.4, 41.2, 44.7, 42.0,
#        48.4, 38.3, 40.5, 45.1, 38.8, 47.0, 36.6, 43.9, 43.4, 36.0, 45.7,
#        37.5, 46.4, 45.8, 46.1, 47.8, 44.5, 41.4, 45.0, 39.1, 45.1, 45.4,
#        46.9, 45.1, 38.5, 42.3, 46.9, 40.2, 53.3, 44.7, 37.4, 45.3, 44.1,
#        37.8, 46.3, 46.4, 38.1, 46.9, 37.8, 46.2, 37.0, 39.7, 54.4, 36.3,
#        48.6, 42.9, 39.4, 41.5, 42.8, 43.9, 41.2, 44.4, 38.4, 44.5, 37.4,
#        35.5, 44.0, 48.6, 40.8, 47.3, 44.6, 41.4, 46.5, 36.2, 41.7, 43.2,
# ...

# %%
datanew = data2
datanew['CHE'] = datanew['CHE'].astype(int)

# %%
datanew['CREA'] = datanew['CREA'].astype(int)

# %%
datanew['GGT'] = datanew['GGT'].astype(int)

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       615 non-null    object
#  4   ALP       615 non-null    object
#  5   ALT       615 non-null    object
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    int32
#  9   CHOL      615 non-null    object
#  10  CREA      615 non-null    int32
#  11  GGT       615 non-null    int32
#  12  PROT      615 non-null    object
# dtypes: float64(2), int32(3), int64(1), object(7)
# memory usage: 55.4+ KB

# %%
sns.pairplot(datanew, vars=['Age', 'CHE', 'CREA', 'GGT'])

# %%
data2.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       615 non-null    object
#  4   ALP       615 non-null    object
#  5   ALT       615 non-null    object
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    int32
#  9   CHOL      615 non-null    object
#  10  CREA      615 non-null    int32
#  11  GGT       615 non-null    int32
#  12  PROT      615 non-null    object
# dtypes: float64(2), int32(3), int64(1), object(7)
# memory usage: 55.4+ KB

# %%
sns.boxplot(data2.Age)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data2['ALB'] = data2['ALB'].map(lambda x: x if type(x)==float else np.nan)
data2['ALP'] = data2['ALP'].map(lambda x: x if type(x)==float else np.nan)
data2['ALT'] = data2['ALT'].map(lambda x: x if type(x)==float else np.nan)
data2['CHOL'] = data2['CHOL'].map(lambda x: x if type(x)==float else np.nan)
data2['PROT'] = data2['PROT'].map(lambda x: x if type(x)==float else np.nan)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       614 non-null    float64
#  4   ALP       597 non-null    float64
#  5   ALT       614 non-null    float64
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    int32
#  9   CHOL      605 non-null    float64
#  10  CREA      615 non-null    int32
#  11  GGT       615 non-null    int32
#  12  PROT      614 non-null    float64
# dtypes: float64(7), int32(3), int64(1), object(2)
# memory usage: 55.4+ KB

# %%
sns.boxplot(x='Sex', y='ALB', data=data2, hue="Category")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='ALB'>

# %%
plt.figure(figsize=(6,6))
plt.scatter(data2['Age'], data2['PROT'])
plt.xlabel('Age')
plt.ylabel('Proteind')
plt.title('Protein as per age')
# Out:
# Text(0.5, 1.0, 'Protein as per age')

# %%
plt.figure(figsize=(6,6))
plt.pie(data2['Category'].value_counts(), labels=data2['Category'].unique())
plt.legend()
plt.title('Different Categories')
# Out:
# Text(0.5, 1.0, 'Different Categories')

# %%
plt.figure(figsize=(8,8))
data2.groupby('Category')['CHOL'].mean().plot(kind='bar')
plt.xlabel('Age')
plt.ylabel('CHOL')
plt.title('Chol in blood as per age')
# Out:
# Text(0.5, 1.0, 'Chol in blood as per age')

# %%
plt.hist(data2['ALB'], color='green')
plt.xlabel('ALB')
plt.ylabel('Count')
plt.title('Count of ALB')
# Out:
# Text(0.5, 1.0, 'Count of ALB')

# %%
sns.distplot(data2['ALT'])
plt.xlabel('ALT')
plt.ylabel('Count')
plt.title('Count of ALT')
# Out:
# Text(0.5, 1.0, 'Count of ALT')

# %%
plt.figure(figsize=(6,6))
sns.jointplot(data2['ALB'], data2['ALP'])

# %%
sns.stripplot(x='Sex', y='PROT', data=data2)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='PROT'>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x='Category', y='CHE', data=data2)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='CHE'>

# %% [markdown]
# From all the EDA done, we can conclude that the dataset given can be used for clustering as well as classfication problem.
#
# We can either group the data together accroding to different features or predict the category of the blood. The missing values in the dataset has been treated and the data is spreaded among all the columns. All the columns are important for predicting the values of the target variable. Most of the poeple in the data set are blood donor and the model should give a weightage to other options for more efficiancy.
#
# Feature Engneering can be done next to get more details from the data and data can be converted into dummies for enhancing the quality of the model.
#
# Once the Feature Engineering is done, we can split the data set into test and train and suitable model can be selected for the probelem. The test data can be used to check the efficiency of the model and hyperparameters can be tune for improving the performance.
